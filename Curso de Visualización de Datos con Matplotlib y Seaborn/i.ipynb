# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x=['A','B','C'],y=[1,3,7])
plt.show()

# %%
sns.set_theme(style='dark',palette='muted', font='verdana', font_scale=1)
sns.barplot(x=['A','B','C'],y=[4,3,7])
plt.show()
