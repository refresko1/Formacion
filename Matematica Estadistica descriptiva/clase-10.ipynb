# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('cars.csv')

# %%
df['price_usd'].std()
# Out:
# 6428.1520182029035

# %%
rango = df['price_usd'].max() -df['price_usd'].min()
print(rango)
# Out:
# 49999.0

# %%
mediana = df['price_usd'].median()
Q1 = df['price_usd'].quantile(q=0.25)
Q2 = df['price_usd'].quantile(q=0.5)
Q3 = df['price_usd'].quantile(q=0.75)
min_val = df['price_usd'].quantile(q=0)
max_val = df['price_usd'].quantile(q=1)

print(min_val,Q1, mediana,  Q2, Q3, max_val)
# Out:
# 1.0 2100.0 4800.0 4800.0 8990.0 50000.0

# %%
iqr=Q3-Q1
iqr
# Out:
# 6890.0

# %%
#Distribucion simetrica
min_limit = Q1 -1.5 *iqr
max_limit = Q3 +1.5 *iqr
print(min_limit, max_limit)
# Out:
# -8235.0 19325.0

# %%
sns.histplot(df['price_usd'])
# Out:
# <Axes: xlabel='price_usd', ylabel='Count'>

# %%
sns.boxplot(x= 'engine_fuel', y= 'price_usd', data=df)
#sns.boxplot(x= 'price_usd', data=df)
# Out:
# <Axes: xlabel='engine_fuel', ylabel='price_usd'>
