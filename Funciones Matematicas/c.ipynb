# %%
import matplotlib.pyplot as plt   # librería para graficar
import numpy as np                # librería para manejo de vectores y utilidades matemáticas

# %% [markdown]
# Funciones trascendentes
# Son funciones que no pueden ser expresadas con polinomios.### Funciones polinómicas

# %% [markdown]
# Funciones trigonométricas
# Algunos ejemplos son las funciones  cos(x) ,  sen(x)  y  tan(x)

# %%
N=100
x = np.linspace(-10,10, num=N)

# %%
def f(x):
  return np.cos(x)

y = f(x)

plt.plot(x,y)

# %% [markdown]
# Función exponencial
# Tienen la forma de
# f(x)=ax
# donde la base  a  es una constante positiva. Un gran ejemplo de una función exponencial es usando la base como el número de euler:
#
# f(x)=ex

# %%
def f(x):
  return np.exp(x)

y=f(x)

plt.plot(x,y)

# %% [markdown]
# Función logaritmo
# El logaritmo está definido por la relación:
#
# logb(x)=n⟺x=bn
#
# donde:
#
# b  es la base.
# n  es el exponente al que está elevado la base.
# x  es el resultado de elevar la base  b  al exponente  n
# Ejemplo:
#
# Teniendo b=2 y n=8, entonces:
#
# 28=256
#
# Por lo que  x=256 . Calculando el logaritmo base 2 de  x  es:
#
# log2(256)=8

# %%
def f(x):
  return np.log2(x)

x = np.linspace(0.001,256, num=100)
plt.plot(x,f(x))
