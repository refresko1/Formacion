# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
def f(x):
    return np.sin(x)

x= np.linspace(-10,10, num=1000)

def df(f):
    h = 0.00001
    return (f(x+h)-f(x))/h

y=f(x)
dfv =df(f)


plt.plot(x,y,'b')
plt.plot(x,dfv,'r')
plt.grid()
